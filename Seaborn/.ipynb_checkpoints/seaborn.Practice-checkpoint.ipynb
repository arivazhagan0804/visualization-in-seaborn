# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## distibution Plots
#
# ## displot
#       combination of kde and barplot.kde allow us probability distribution of data.

# %%
sns.displot(tips['total_bill'],kde=True)

# %% [markdown]
# ## jointplot
#
#     combine two displot for bivariate.
#
#     default kind is scatter.
#
#     hex,kde,residial,regression.

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.displot(x='total_bill',y='tip',data=tips,kind='kde')

# %% [markdown]
# ## pairplot
#
#     It will identify and plot pairwise relationship for all columns in the dataset.Categorical data distingushed
#
#     the hue option.
#
#     diagonal plot --> 'kde' or 'hist'
#
#     non diagonal plot --> scatter,reg

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips,hue='sex',kind='scatter',diag_kind='kde')

# %%
sns.pairplot(tips,hue='day',kind='reg',diag_kind='hist')

# %%
sns.pairplot(tips,hue='time',kind='scatter',diag_kind='kde')

# %% [markdown]
# ## rugplot
#   It is  actually  a very simple concept.They just draw a dash mark for every point on a univariate distribution.

# %%
sns.rugplot(tips['total_bill'])
s
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# ## Categorical data plots
# ## barplot
#
#      It will give us numerical information for a categorical data type.
#
#      It is default by mean.we can use agg function such us np.std,np.max,np.min.

# %% [markdown]
# ## countplot
#
#     It similar to the bar plot instead aggregated information about the data.It display directaly that count of category in the data.

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x='smoker',hue='sex',data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='total_bill',data=tips,hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='count'>

# %% [markdown]
# ## Boxplot
#   It is used for identify the 'outliers'using a method that is a function of the  Inter quartile range.

# %%
sns.boxplot(x='total_bill',y='time',hue='sex',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='time'>

# %%
sns.boxplot(x='total_bill',y='day',hue='sex',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## violinplot
#
#  It is feature a kernal density estimator of a under lying distribution.

# %%
sns.violinplot(x='total_bill',y='day',hue='sex',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## stripplot
#
#    It is also an univarible.you can show your data.It is show in overlab.

# %%
sns.stripplot(x='total_bill',y='tip',hue='sex',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## swarmplot
#
#    It is similar to the stripplot.But the points are adjusted.so,that they don't overlab.

# %%
sns.swarmplot(x='total_bill',y='time',hue='sex',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='time'>

# %% [markdown]
# ## catplot

# %% [markdown]
# carplot is a general plot type for categorical data.It necessary to provide 'kind' to control the type of the
# categorical data plot we get.

# %%
sns.catplot(x='time',y='total_bill',data=tips,kind='',hue='sex',col='day')

# %%
sns.catplot(x='day',y='total_bill',data=tips,hue='sex',kind='violin',col='time')

# %% [markdown]
# ## Matrix plot

# %% [markdown]
# Matrix plot display the data in the format of a colored matrix.

# %%
df=sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
df['year'].unique()
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960], dtype=int64)

# %%
df['month'].unique()
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', ..., 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# Length: 12
# Categories (12, object): ['Jan', 'Feb', 'Mar', 'Apr', ..., 'Sep', 'Oct', 'Nov', 'Dec']

# %%
pivot=df.pivot(index='month',columns='year',values='passengers')
pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# ## heatmap

# %% [markdown]
# heatmap creates a colored matrix of the data.which is already in the matrix plot.

# %%
sns.heatmap(pivot,linecolor='white',linewidths=2)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
fig,ax = plt.subplots(figsize=(10,8))

sns.heatmap(data=pivot.loc[:,'1957':],annot=True,linecolor='white',linewidths=2)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
corr=tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,linecolor='white',linewidths=2)
# Out:
# <Axes: >

# %% [markdown]
# ## clustermap

# %% [markdown]
# It creates a hierarchical relationship to the headmap plot

# %%
sns.clustermap(pivot)

# %% [markdown]
# ## Grid plots
#
#     It allow us to plot multiplots in columns and rows.

# %% [markdown]
# ## Pair grid
#     It provides the posibility to plot together multiplots.It is more flexcible version of the  pair plot.

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df)

# %%
a=sns.PairGrid(df)
a.map_diag(sns.distplot)
a.map_upper(plt.scatter)
a.map_lower(sns.kdeplot)
# Out:
# D:\hari\ana\Lib\site-packages\seaborn\axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# D:\hari\ana\Lib\site-packages\seaborn\axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
b=sns.PairGrid(df,hue='species')
b.map_diag(sns.displot)
b.map_upper(plt.scatter)##
b.map_lower(sns.kdeplot)
# Out:
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Facet Grid
#   The most important difference of pairplot compared to pairgrid is that we can select columns to visulize.

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
f=sns.FacetGrid(tips,row='smoker',col='time')
f.map(sns.displot,'total_bill',kde=True)
# Out:
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
f=sns.FacetGrid(tips,row='sex',col='time')
f.map(plt.hist,'total_bill')

# %%
g=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
g.map(plt.scatter,'total_bill','tip')
plt.legend()

# %% [markdown]
# ## JointGrid![download.png](attachment:bbff53e9-a7e7-4bf0-8e34-83bfa617a37b.png)

# %% [markdown]
# ## JointGrid

# %%
j=sns.JointGrid(tips,x='total_bill',y='tip',hue='sex')
j=j.plot(sns.distpot,sns.regplot)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 2
#       1 j=sns.JointGrid(tips,x='total_bill',y='tip',hue='sex')
# ----> 2 j=j.plot(sns.distpot,sns.regplot)
#
# AttributeError: module 'seaborn' has no attribute 'distpot'

# %%
## lmplot
   Combination of lmplot and FacetGridplot.

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'])

# %%
sns.lmplot(tips,x='total_bill',y='tip',hue='sex',row='sex',col='day')

# %% [markdown]
# ##  Editing plot properties

# %%
sns.set_style('whitegrid')
sns.countplot(x='sex',data=tips,palette='rainbow')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7588\870691927.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='rainbow')
# <Axes: xlabel='sex', ylabel='count'>
