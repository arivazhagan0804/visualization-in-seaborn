# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r'C:\Users\ELCOT\Desktop\csv file\Chocolate Sales.csv')
df
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   object
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   object
#  4   Amount         1094 non-null   object
#  5   Boxes Shipped  1094 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 51.4+ KB

# %%
df.describe()
# Out:
#        Boxes Shipped
# count    1094.000000
# mean      161.797989
# std       121.544145
# min         1.000000
# 25%        70.000000
# 50%       135.000000
# 75%       228.750000
# max       709.000000

# %%
df['Country'].unique()
# Out:
# array(['UK', 'India', 'Australia', 'New Zealand', 'USA', 'Canada'],
#       dtype=object)

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
df['Amount'].plot.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 df['Amount'].plot.hist()
#
# File D:\hari\ana\Lib\site-packages\pandas\plotting\_core.py:1409, in PlotAccessor.hist(self, by, bins, **kwargs)
#    1349 def hist(
#    1350     self, by: IndexLabel | None = None, bins: int = 10, **kwargs
#    1351 ) -> PlotAccessor:
#    1352     """
#    1353     Draw one histogram of the DataFrame's columns.
#    1354
#    (...)
#    1407         >>> ax = df.plot.hist(column=["age"], by="gender", figsize=(10, 8))
#    1408     """
# -> 1409     return self(kind="hist", by=by, bins=bins, **kwargs)
#
# File D:\hari\ana\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# ...

# %%
df['days']=pd.to_datetime(df['Date'])
df['year']=df['days'].apply(lambda x:x.year)
df['year'].unique()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_16004\2393386040.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['days']=pd.to_datetime(df['Date'])
# array([2022], dtype=int64)

# %%
df['month']=df['days'].apply(lambda x:x.month)
df['month'].unique()
# Out:
# array([1, 8, 7, 4, 2, 6, 3, 5], dtype=int64)

# %%
plt.style.use('ggplot')
plt.figure(figsize=(8,6),dpi=200)
df.groupby(df['days'])['Boxes Shipped'].mean().plot()
# Out:
# <Axes: xlabel='days'>

# %%
plt.style.use('ggplot')
plt.figure(figsize=(30,6),dpi=200)
month=df.groupby(df['month']).count()
month.plot()
# Out:
# <Axes: xlabel='month'>
