# %% [markdown]
# Name  : Arivazhagan.B
#
# Title : seaborn Excercise
#
# Email : arivazhagan45678@gmail.com

# %% [markdown]
#  ## I will working with a famous titanic dataset for these excercise.For now ,I will focus on the visualization of the data with seaborn.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('whitegrid')

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ## jointplot
#    It give us combines fare and age for bivariate data in dataset

# %%
df['age'].mean()
# Out:
# 29.69911764705882

# %%
sns.set_context('poster',font_scale=.5)
sns.jointplot(x='fare',y='age',data=df,hue='sex')

# %% [markdown]
# ## displot
#  It combination of kde(kernal density estimator) and barplot.kde show us probability distribution of data.
#
#  It  will give us maximum count for fare in the data.

# %%
sns.displot(df['fare'],bins=10,color='red')

# %% [markdown]
# ## Box plot
#  It will give us to identify the outliers in you data.using a method that is a function of the inter quartile range.

# %%
plt.figure(figsize=(10,6))
sns.set_context('poster',font_scale=1)
sns.boxplot(x='class',y='age',data=df,palette='rainbow')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_5980\1410729083.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class',y='age',data=df,palette='rainbow')
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# ## swarmplot
#  it will give us univarible in our data.

# %%
sns.swarmplot(x='class',y='age',data=df,palette='rainbow')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_5980\3618329385.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='class',y='age',data=df,palette='rainbow')
# <Axes: xlabel='class', ylabel='age'>
# D:\hari\ana\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## countplot
#  It will give us count of sex column in your data.

# %%
sns.countplot(data=df,x='sex',palette='rainbow')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_5980\2695207385.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='sex',palette='rainbow')
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## headmap
#  it will give us corr() relation in your data

# %%
df.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df[['fare','age']].corr()
# Out:
#           fare       age
# fare  1.000000  0.096067
# age   0.096067  1.000000

# %%
sns.heatmap(df[['fare','age']].corr(),linewidths=1,linecolor='yellow')
# Out:
# <Axes: >

# %% [markdown]
# ## FacetGrid
#    It will give us select the column to visualize.

# %%
plt.figure(figsize=(15,6))
sns.set_context('poster',font_scale=.5)
sex=sns.FacetGrid(df,col='sex')
sex.map(plt.hist,'age')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
Count of people alive and death in our dataset.

# %%
sns.countplot(data=df,x='alive',hue='sex')
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
alive=sns.FacetGrid(data=df,col='embark_town')
alive.map(sns.countplot,'alive')
# Out:
# D:\hari\ana\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
