# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# info()-It will give us to number of rows and columns,nan null values ,data type and memory storage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# describe()-It will give us aggregate function.Ex : np.sum,np.mean,np.max,np.min

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
dinner=df[df['time']=='Dinner']['total_bill'].value_counts().head()
dinner
# Out:
# total_bill
# 18.29    2
# 21.01    2
# 20.29    2
# 17.92    2
# 7.25     2
# Name: count, dtype: int64

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
lunch=df[df['time']=='Lunch']['total_bill'].value_counts().head()
lunch
# Out:
# total_bill
# 13.42    3
# 13.00    2
# 15.98    2
# 18.64    1
# 28.44    1
# Name: count, dtype: int64

# %%
sns.countplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 sns.countplot(df,x='lunch',y='dinner')
#
# File D:\hari\ana\Lib\site-packages\seaborn\categorical.py:2629, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2627     y = 1 if list(x) else None
#    2628 elif x is not None and y is not None:
# -> 2629     raise TypeError("Cannot pass values for both `x` and `y`.")
#    2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    (...)
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#
# TypeError: Cannot pass values for both `x` and `y`.

# %%
sns.displot(df['total_bill'])

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='resid')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.set_style('darkgrid')
sns.despine()
sns.displot(df['total_bill'],kde='True',bins=10)

# %%
sns.displot(df,x='total_bill')

# %%
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',kind='kde',data=df)

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='resid')

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex')

# %% [markdown]
# pairplot-It will identify and pairwise relationship for all columns in the dataset.the categorical data is distingushed by
#
# the hue .

# %%
sns.pairplot(df,hue='day',kind='reg',diag_kind='hist')

# %%
sns.pairplot(df,hue='day')

# %%
sns.kdeplot(x='total_bill',y='tip',hue='sex',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
barplot-it give us numerical information for categorigal datatype.It default by mean .we can also use aggrecate function.
np.std,np.max,np.min,np.mean,np.

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='sex',y='total_bill',hue='day',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
countplot-It is similar to the barplot.It display that count of the category in the data.

# %%
sns.countplot(x='smoker',hue='day',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
Boxplot-It is used to the identify the  outlayers .Using a method that function of the inter quartile range

# %%
sns.boxplot(x='total_bill',hue='sex',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(x='total_bill',y='time',hue='sex',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='total_bill', ylabel='time'>

# %%
sns.boxplot(x='tip',y='sex',hue='day',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
sns.boxplot(x='tip',y='sex',hue='time',data=df,palette='coolwarm')
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
violinpot-It serves similer to the purpose of boxplot.but  use kde to represents the distribution of the data.

# %%
sns.violinplot(x='total_bill',y='sex',data=df,hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.violinplot(x='tip',y='sex',hue='day',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
stripplot - This is also univariable .you can show your data points.data show in overlab.

# %%
sns.set_style('whitegrid')
sns.set_context('poster',font_scale=0.5)
plt.figure(figsize=(5,5),dpi=200)
sns.stripplot(x='time',y='total_bill',data=df)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.stripplot(x='time',y='total_bill',hue='sex',data=df)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# swarmplot()-It is similar to the stripplot.but data points are adjusted .so,that they don't adjusted.

# %%
sns.swarmplot(x='total_bill',y='time',hue='sex',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='time'>

# %%
sns.swarmplot(x='time',y='total_bill',hue='sex',data=df)
sns.violinplot(x='time',y='total_bill',hue='sex',data=df)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# catplot-It is general plot type for categorical data.It necessary to provide 'kind' control the type of the categorical
#
# plot we get.

# %%
sns.catplot(x='sex',y='total_bill',hue='time',data=df,kind='bar',estimator=np.min)

# %%
df=sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ## Matrix plot
#
#     Matrix plots display the data in the format of a colored matrix.

# %%
pivot=df.pivot_table(values="passengers",index='month',columns='year')
pivot
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_5248\2711542093.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot=df.pivot_table(values="passengers",index='month',columns='year')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %% [markdown]
# ## headmap
# headmap creates matrix of a data which is already in the matrix format

# %%
fig,axes=plt.subplots(figsize=(10,6))
sns.heatmap(pivot,linewidths=0.2,annot=True,linewidths=2)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
ax,fig=plt.subplots(figsize=(10,6),dpi=150)
sns.heatmap(data=pivot.loc[:,1957:],annot=True,linewidths=0.2)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
corr=tips[['total_bill','tip','size']]
corr
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
sns.heatmap(corr.corr(),annot=True,linewidths=2)
# Out:
# <Axes: >

# %% [markdown]
# ## cluster map
#
#    clustermap creates a hierarchical relationship to the headmap matrix.

# %%
sns.clustermap(data=pivot)

# %% [markdown]
# ## Grid plot
#
#       grid plot create a plot multiplot in the  rows and columns.

# %% [markdown]
# ## pairgrid
#
#     It provides possible to together multiple plots.A more flexible version of pairplot

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(data=iris,hue=)

# %%
iris=sns.PairGrid(data=iris)
iris.map_diag(sns.displot)
iris.map_lower(sns.kdeplot)
iris.map_upper(plt.scatter)
# Out:
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## FaceGrid
#     The most important differnts of facegrid to compaired to pairplot and pairgrid is that we can select the column to visualize.

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
FaceGrid=sns.FacetGrid(data=df,row='smoker',col='time')
FaceGrid.map(sns.displot,'tip',kde=True)
# Out:
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\hari\ana\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## lmplot
#
#   combination of linear regression and FaceGrid plot.

# %%
sns.lmplot(x='total_bill',y='tip',data=df)

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',data=df,markers=['o','v'],scatter_kws={'s':150})

# %%
sns.lmplot(x='total_bill',y='tip',data=df,col='sex',row='smoker')

# %%
sns.lmplot(x='total_bill',y='tip',data=df,col='day',hue='smoker')
